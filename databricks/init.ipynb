# %% [markdown]
# # Initializing schemas and catalog

# %%
# %sql
CREATE CATALOG IF NOT EXISTS `top_songs_worldwide`;
CREATE SCHEMA IF NOT EXISTS `top_songs_worldwide`.bronze;
CREATE SCHEMA IF NOT EXISTS `top_songs_worldwide`.dbt_schema;
CREATE SCHEMA IF NOT EXISTS `top_songs_worldwide`.gold;
